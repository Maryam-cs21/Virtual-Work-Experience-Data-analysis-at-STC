# %% [markdown]
# # STC Jawwy

# %%
"""
Here we install libraries that are not installed by default
Example:  pyslsb
Feel free to add any library you are planning to use.
"""
# !pip install pyxlsb

# %%
# Import the required libraries
"""
Please feel free to import any required libraries as per your needs
"""
import pandas as pd     # provides high-performance, easy to use structures and data analysis tools
import pyxlsb           # Excel extention to read xlsb files (the input file)
import numpy as np      # provides fast mathematical computation on arrays and matrices

# %% [markdown]
# # Jawwy dataset
# The dataset consists of details about each customer and the movies and/or tv shows watched in addition to the genre.
#
# You are required to work on task three to build a recommendation engine for our platform to Recommend movies to usesrs that they might be interested in¶

# %%
dataframe = pd.read_excel("stc TV Data Set_T3.xlsb",index_col=0)
# Please make a copy of dataset if you are going to work directly and make changes on the dataset
# you can use   df=dataframe.copy()

# %%
# check the data shape
dataframe.shape
# Out:
# (1048575, 5)

# %%
# display the first 5 rows
dataframe.head()
# Out:
#    user_id_maped          program_name  rating      date_ program_genre
# 0          26138            100 treets       1 2017-05-27         Drama
# 1           7946                 Moana       1 2017-05-21     Animation
# 2           7418  The Mermaid Princess       1 2017-08-10     Animation
# 3          19307  The Mermaid Princess       2 2017-07-26     Animation
# 4          15860             Churchill       2 2017-07-07     Biography

# %%
# describe the numeric values in the dataset
dataframe.describe()
# Out:
#        user_id_maped        rating                          date_
# count   1.048575e+06  1.048575e+06                        1048575
# mean    1.709266e+04  2.497283e+00  2017-10-04 00:23:20.346183936
# min     1.000000e+00  1.000000e+00            2017-03-14 00:00:00
# 25%     8.253000e+03  1.000000e+00            2017-06-10 00:00:00
# 50%     1.714900e+04  2.000000e+00            2017-10-14 00:00:00
# 75%     2.566500e+04  3.000000e+00            2018-01-21 00:00:00
# max     3.428000e+04  4.000000e+00            2018-04-30 00:00:00
# std     1.003513e+04  1.119837e+00                            NaN

# %%
# check if any column has null value in the dataset
dataframe.isnull().any()
# Out:
# user_id_maped    False
# program_name     False
# rating           False
# date_            False
# program_genre    False
# dtype: bool

# %%
df=dataframe.copy()
# Use get_dummies() to create one-hot encoding for movie names
dummies = pd.get_dummies(df['program_name'])

# %%
dummies
# Out:
#          #FollowFriday  10 Days in a Madhouse  100 treets  101 Dalmatians  \
# 0                False                  False        True           False
# 1                False                  False       False           False
# 2                False                  False       False           False
# 3                False                  False       False           False
# 4                False                  False       False           False
# ...                ...                    ...         ...             ...
# 1048570          False                  False       False           False
# 1048571          False                  False       False           False
# 1048572          False                  False       False           False
# 1048573          False                  False       False           False
# 1048574          False                  False       False           False
#
#          102 Dalmatians   11.6  12 Monkeys  Arms Of Mine  12 Monkeys  Atari  \
# ...

# %%
# Create a DataFrame for movie IDs
movie_ids = pd.DataFrame(dummies.columns, columns=['program_name'])
movie_ids['movie_id'] = range(1, len(movie_ids) + 1)

# Merge movie IDs back into the original DataFrame
df_with_ids = pd.merge(df, movie_ids, on='program_name')

# %%
df_with_ids.tail(10)
# Out:
#          user_id_maped                                      program_name  \
# 1048565          12453                  Criminal Minds     The Road Home
# 1048566            348  Driver Dan’s tory Train  (T)    The Perfect Game
# 1048567           2762                       Lel Hob Zaman Akhar    Ep15
# 1048568          12453                      Criminal Minds     The Fight
# 1048569          12453                       Criminal Minds     Painless
# 1048570          12453                           Criminal Minds     Open
# 1048571          12453                     Criminal Minds     True Night
# 1048572          12453                     Criminal Minds     The Return
# 1048573          12453                  Criminal Minds     Nanny Dearest
# 1048574          15305            Pinky Dinky Doo      Tyler's illy hirt
#
#          rating      date_ program_genre  movie_id
# 1048565       4 2017-06-15         Crime      1738
# 1048566       3 2017-04-18     Animation      2227
# ...

# %%
import re
#Remove any unneccessry characters from the program name
df_with_clean_titles =df_with_ids.copy()
def clean_title(program_name):
    program_name = re.sub("[^a-zA-Z0-9 ]", "", program_name)
    return program_name

# %%
#apply the clean_title function
df_with_clean_titles["clean_program_name"] = df_with_clean_titles["program_name"].apply(clean_title)

# %%
df_with_clean_titles
# Out:
#          user_id_maped                            program_name  rating  \
# 0                26138                              100 treets       1
# 1                 3422                              100 treets       2
# 2                15168                              100 treets       1
# 3                 2446                              100 treets       2
# 4                29911                              100 treets       3
# ...                ...                                     ...     ...
# 1048570          12453                 Criminal Minds     Open       4
# 1048571          12453           Criminal Minds     True Night       4
# 1048572          12453           Criminal Minds     The Return       4
# 1048573          12453        Criminal Minds     Nanny Dearest       3
# 1048574          15305  Pinky Dinky Doo      Tyler's illy hirt       3
#
#              date_ program_genre  movie_id  \
# 0       2017-05-27         Drama         3
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ngram_range=(1,2))

tfidf = vectorizer.fit_transform(df_with_clean_titles["clean_program_name"])

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
#Clac the similarity between the searched title and the program_names
def search(title):
    title = clean_title(title)
    query_vec = vectorizer.transform([title])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity, -5)[-5:]#return the 5 movies with greatest similarity
    results = df_with_clean_titles.iloc[indices].iloc[::-1]# reverse the order

    return results

# %%
# !pip install ipywidgets
# !jupyter labextension install @jupyter-widgets/jupyterlab-manager
# Out:
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# ...
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir] [--paths] [--json]
#                [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: bundlerextension console dejavu execute kernel kernelspec migrate nbclassic
# ...

# %%
import ipywidgets as widgets
from IPython.display import display

movie_input = widgets.Text(
    value='Toy Story',
    description='Movie Title:',
    disabled=False
)
movie_list = widgets.Output()

def on_type(data):
    with movie_list:
        movie_list.clear_output()
        title = data["new"]
        if len(title) > 5:
            display(search(title))

movie_input.observe(on_type, names='value')


display(movie_input, movie_list)
# Out:
# Text(value='Toy Story', description='Movie Title:')
# Output()

# %%
# Find the users that they liked the same movie
movie_id=1
similar_users = df_with_clean_titles[(df_with_clean_titles["movie_id"] == movie_id) & (df_with_clean_titles["rating"] >= 4)]["user_id_maped"].unique()

# %%
similar_users
# Out:
# array([29711, 26929,  5050,  1670,  2015,  8028, 32113, 21015,  9334,
#        21852,  9006, 22407, 26601, 27880, 11387,  8754, 26275, 16680,
#         8726, 15795,  2375,  5864, 21343, 21735,  3053])

# %%
matched_users = df_with_clean_titles[df_with_clean_titles['user_id_maped']==similar_users[0]]
matched_users
# Out:
#         user_id_maped          program_name  rating      date_ program_genre  \
# 79450           29711      Extraterrestrial       1 2017-07-11        Horror
# 79453           29711      Extraterrestrial       1 2017-07-11        Horror
# 112366          29711         The Boss Baby       1 2017-07-09     Animation
# 140649          29711     Collateral Beauty       1 2017-07-10         Drama
# 158502          29711           Broken Vows       2 2017-07-10      Thriller
# 180493          29711                 Rings       1 2017-07-09        Horror
# 233063          29711         #FollowFriday       1 2017-07-11      Thriller
# 233067          29711         #FollowFriday       2 2017-07-11      Thriller
# 233069          29711         #FollowFriday       1 2017-07-18      Thriller
# 233071          29711         #FollowFriday       4 2017-07-11      Thriller
# 243150          29711          The Neighbor       2 2017-07-11        Horror
# ...

# %%
# Find the movies that the users in (similar_users) liked
similar_user_recs = df_with_clean_titles[(df_with_clean_titles["user_id_maped"].isin(similar_users)) & (df_with_clean_titles["rating"] >= 4)]["movie_id"]

# %%
similar_user_recs
# Out:
# 1831          3
# 2078       4938
# 2341       4938
# 2919       4938
# 3062       4938
#            ...
# 1045782    4467
# 1045987    4470
# 1046663    4478
# 1047801    3235
# 1047810    6662
# Name: movie_id, Length: 1987, dtype: int64

# %%
#Find the movies that more that 10% of the people in (similar_user_recs) liked
similar_user_recs_count = similar_user_recs.value_counts() / len(similar_users)

similar_user_recs_most_liked=similar_user_recs_count[similar_user_recs_count > .1]

# %%
similar_user_recs_most_liked.head(10)
# Out:
# movie_id
# 6668    3.28
# 580     1.60
# 1       1.24
# 7440    1.16
# 3156    1.08
# 6544    0.96
# 588     0.88
# 4938    0.80
# 6401    0.68
# 1022    0.68
# Name: count, dtype: float64

# %%
#Find the users in the whole dataset that also liked the movies in (similar_user_recs_most_liked) or all the users that watch the programs that are recommended to us
all_users = df_with_clean_titles[(df_with_clean_titles["movie_id"].isin(similar_user_recs_most_liked.index)) & (df_with_clean_titles["rating"] >= 4)]

# %%
all_users.tail()
# Out:
#          user_id_maped program_name  rating      date_ program_genre  \
# 1037904          26275     Underdog       4 2017-06-11        Action
# 1037907          26275     Underdog       4 2017-06-13        Action
# 1037910          26275     Underdog       4 2017-06-11        Action
# 1037911          26275     Underdog       4 2017-06-12        Action
# 1037914          26275     Underdog       4 2017-06-12        Action
#
#          movie_id clean_program_name
# 1037904      7510           Underdog
# 1037907      7510           Underdog
# 1037910      7510           Underdog
# 1037911      7510           Underdog
# 1037914      7510           Underdog

# %%
 #finds the proportion of how frequently each movie has been interacted with relative to the total number of unique users.
all_user_recs = all_users["movie_id"].value_counts() / len(all_users["user_id_maped"].unique())

# %%
all_user_recs
# Out:
# movie_id
# 6544    0.543050
# 3971    0.529533
# 6668    0.434029
# 4058    0.369380
# 1021    0.298854
#           ...
# 4977    0.002645
# 1451    0.002057
# 7434    0.002057
# 2414    0.001763
# 7510    0.001763
# Name: count, Length: 179, dtype: float64

# %%
#find each of movies that recomended to us and how much users are similar to us liked them, and how much the avg person liked them.
rec_percentages = pd.concat([similar_user_recs_most_liked, all_user_recs], axis=1)
rec_percentages.columns = ["similar", "all"]

# %%
rec_percentages
# Out:
#           similar       all
# movie_id
# 6668         3.28  0.434029
# 580          1.60  0.030855
# 1            1.24  0.009110
# 7440         1.16  0.205995
# 3156         1.08  0.100206
# ...           ...       ...
# 4245         0.12  0.039965
# 1862         0.12  0.007640
# 6941         0.12  0.005583
# 7901         0.12  0.087276
# 6633         0.12  0.027623
#
# [179 rows x 2 columns]

# %%
rec_percentages["score"] = rec_percentages["similar"] / rec_percentages["all"]

# %%
rec_percentages = rec_percentages.sort_values("score", ascending=False)

# %%
#the higher the score, the better recommendation because it shows that the users similar to you liked the movie while the avg person did not.
rec_percentages
# Out:
#           similar       all       score
# movie_id
# 1            1.24  0.009110  136.120000
# 7510         0.24  0.001763  136.120000
# 5882         0.36  0.003526  102.090000
# 7434         0.20  0.002057   97.228571
# 2414         0.16  0.001763   90.746667
# ...           ...       ...         ...
# 1573         0.16  0.168969    0.946922
# 1454         0.12  0.153394    0.782299
# 3971         0.36  0.529533    0.679845
# 1021         0.20  0.298854    0.669223
# 6721         0.12  0.225683    0.531719
#
# [179 rows x 3 columns]

# %%
df_programs=df_with_clean_titles.copy()

# Keep only the relevant columns
df_filtered = df_programs[['program_name', 'movie_id', 'program_genre', 'clean_program_name']]

# Drop duplicates to keep distinct movie information
df_unique = df_filtered.drop_duplicates()

# Display the resulting DataFrame
df_unique.head()
# Out:
#                           program_name  movie_id program_genre  \
# 0                           100 treets         3         Drama
# 1851                             Moana      4938     Animation
# 9932              The Mermaid Princess      6919     Animation
# 17457                        Churchill      1564     Biography
# 18667  Beavis And Butt-Head Do America      1079     Animation
#
#                    clean_program_name
# 0                          100 treets
# 1851                            Moana
# 9932             The Mermaid Princess
# 17457                       Churchill
# 18667  Beavis And ButtHead Do America

# %%
rec_percentages.head(10).merge(df_unique, left_index=True, right_on="movie_id")
# Out:
#          similar       all       score                       program_name  \
# 233061      1.24  0.009110  136.120000                      #FollowFriday
# 1037885     0.24  0.001763  136.120000                           Underdog
# 645882      0.36  0.003526  102.090000                Sejn Annisaa    Ep.
# 473752      0.20  0.002057   97.228571     Transformers: Dark of the Moon
# 375743      0.16  0.001763   90.746667                               Feed
# 761324      0.12  0.002057   58.337143                             Butter
# 955233      0.88  0.016162   54.448000                      Alhara    Ep.
# 637529      1.60  0.030855   51.855238                    Al ayyad    Ep.
# 365762      0.32  0.006171   51.855238       Teenage Mutant Ninja Turtles
# 365763      0.32  0.006171   51.855238       Teenage Mutant Ninja Turtles
# 284042      0.12  0.002645   45.373333  Murder  he Baked: A Deadly Recipe
#
#          movie_id program_genre                clean_program_name
# ...

# %%
"""
TODO build your Recommender system to Highlight Programs that usesrs might be interested in
"""
# Out:
# '\nTODO build your Recommender system to Highlight Programs that usesrs might be interested in\n'

# %%
def find_similar_movies(movie_id):
  similar_users = df_with_clean_titles[(df_with_clean_titles["movie_id"] == movie_id) & (df_with_clean_titles["rating"] >= 4)]["user_id_maped"].unique()
  similar_user_recs = df_with_clean_titles[(df_with_clean_titles["user_id_maped"].isin(similar_users)) & (df_with_clean_titles["rating"] >= 4)]["movie_id"]

  similar_user_recs_count = similar_user_recs.value_counts() / len(similar_users)
  similar_user_recs_most_liked=similar_user_recs_count[similar_user_recs_count > .1]

  all_users = df_with_clean_titles[(df_with_clean_titles["movie_id"].isin(similar_user_recs_most_liked.index)) & (df_with_clean_titles["rating"] >= 4)]
  all_user_recs = all_users["movie_id"].value_counts() / len(all_users["user_id_maped"].unique())

  rec_percentages = pd.concat([similar_user_recs_most_liked, all_user_recs], axis=1)
  rec_percentages.columns = ["similar", "all"]

  rec_percentages["score"] = rec_percentages["similar"] / rec_percentages["all"]
  rec_percentages = rec_percentages.sort_values("score", ascending=False)


  df_programs=df_with_clean_titles.copy()

  # Keep only the relevant columns
  df_filtered = df_programs[['program_name', 'movie_id', 'program_genre', 'clean_program_name']]

  # Drop duplicates to keep distinct movie information
  df_unique = df_filtered.drop_duplicates()

  # Display the resulting DataFrame
  df_unique.head()

  return rec_percentages.head(10).merge(df_unique, left_index=True, right_on="movie_id")[["score", "program_name", "program_genre"]]

# %%
"""
TODO show the recommendations (top 5) for the people who watched "Moana" movie
"""
# Out:
# '\nTODO show the recommendations (top 5) for the people who watched "Moana" movie\n'

# %%
import ipywidgets as widgets
from IPython.display import display

movie_name_input = widgets.Text(
    value='Toy Story',
    description='Movie Title:',
    disabled=False
)
recommendation_list = widgets.Output()

def on_type(data):
    with recommendation_list:
        recommendation_list.clear_output()
        title = data["new"]
        if len(title) > 5:
            results = search(title)
            movie_id = results.iloc[0]["movie_id"]
            display(find_similar_movies(movie_id).iloc[1:].head(5))
movie_name_input.observe(on_type, names='value')

display(movie_name_input, recommendation_list)
# Out:
# Text(value='Toy Story', description='Movie Title:')
# Output()

# %%
# we import Visualization libraries
# you can ignore and use any other graphing libraries
import matplotlib.pyplot as plt # a comprehensive library for creating static, animated, and interactive visualizations
import plotly #a graphing library makes interactive, publication-quality graphs. Examples of how to make line plots, scatter plots, area charts, bar charts, error bars, box plots, histograms, heatmaps, subplots, multiple-axes, polar charts, and bubble charts.
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
